# %% [markdown]
# ## 1. What is Flask Framework? What are the advantages of Flask Framework?

# %%
## what is Flask? Flask is a microframework for developers, designed to enable them to create and scale web apps quickly and simply.
## Advantages::
   ## 1. Scalability:  Its simplicity of use and few dependencies enable it to run smoothly even as it scales up and up.
   ## 2. Flexibility: It can be easily arranged and moved around.
   ## 3. Easy to negotiate: At its core, the microframework is easy to understand for web developers, 
      # not just saving them time and effort but also giving them more control over their code and what is possible.
   ## 4. Lightweight

# %% [markdown]
# ## Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## OUTPUT::
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Q3. What is App routing in Flask? Why do we use app routes?

# %%
## App routing is used to map the specific URL with the associated function that is intended to perform some task. 
## It is used to access some particular page like Flask Tutorial in the web application.
## In our first application, the URL ('/') is associated with the home function that returns a particular string displayed on the web page.

from flask import Flask  
app = Flask(__name__)  
 
@app.route('/home')  
def home():  
    return "hello, welcome to our website";  
  
if __name__ =="__main__":  
    app.run(debug = True)

# %% [markdown]
# ## Output
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Q4.  Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
#    ## route to show the following details:
#
#     #Company Name: ABC Corporation
#     #Location: India
#     #Contact Detail: 999-999-9999

# %% [markdown]
# ## code:
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Output1:
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Output2:
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function

# %%
## Flask url_for is defined as a function that enables developers to build and generate URLs on a Flask application. 
## Syntax1:: Creating dynamic URL with no key passed:

           ## url_for('<Function name>')
    
## Synatx2:: Creating dynamic URL with a key and corresponding value passed:
          ## url_for('<Function name>',<key> = <value>)
